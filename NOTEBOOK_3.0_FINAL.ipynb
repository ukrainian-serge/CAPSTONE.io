# %% [markdown]
# <center><img src=./imgs_charts/amazon_opening_logo.jpg atl='amazon logo' height="900" width="900"></center>

# %% [markdown]
# <h1 style="text-align:center; font-size:60px;">Analysis of Book vs eBook Review Data</h1>
#
# <p style="text-align:left; font-size:20px;">Static webpage version with interactive <a href="https://docs.bokeh.org/en/latest/docs/gallery.html"> Bokeh</a> charts of this analysis available <a href="https://ukrainian-serge.github.io/CAPSTONE.io/">HERE</a></p>
#
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/ukrainian-serge/amazon_product_reviews/master)
#
# ---
#
# <p style="text-align:left; font-size:20px;">by: Serge Kamilchu<p>
#
# Data source: [S3 amazon AWS review data set](https://s3.amazonaws.com/amazon-reviews-pds/tsv/index.txt)
#
# <h2 style="text-align:left; font-size:20px;">Project Index</h2>
#
# *use these hyper links to jump to different sections*
#
# <ol>
#   <li style="text-align:left; font-size:15px;"><a href='#section1'>Why be interested in books?</a></li>
#   <li style="text-align:left; font-size:15px;"><a href='#section2'>Data questions</a></li>
#   <li style="text-align:left; font-size:15px;"><a href='#section3'>Are paper books even relevant anymore?</a></li>
#   <li style="text-align:left; font-size:15px;"><a href='#section4'>Analysis of paper vs digital title reviews</a></li>
#   <li style="text-align:left; font-size:15px;"><a href='#section5'>Recommendation (END)</a></li>
# </ol>
#
# ---

# %% [markdown]
# <a id="section1"></a>
# <center><img src=./imgs_charts/in_the_dumps.jpg atl='in the dumps' height="900" width="900"/></center>

# %% [markdown]
# <h2 style="text-align:center; font-size:40px;">The greats read books</h2>

# %% [markdown]
# <h2 style="text-align:left; font-size:30px;">Bill Gates</h2>
# <caption style="text-align:left">William Henry Gates III is an American business magnate, software developer, investor, and philanthropist. He is best known as the co-founder of Microsoft Corporation. During his career at Microsoft, Gates held the positions of chairman, chief executive officer, president and chief software architect, while also being the largest individual shareholder until May 2014</caption>
#
# <center><img src="./imgs_charts/bill_2.jfif"
#          height="600" width="600"></center>
#
# <i>"Whether I'm at the office, at home, or on the road, I always have a stack of books I'm looking forward to reading." ~
# Bill Gates</i>
#
# - reads about [50 books per year](https://www.businessinsider.com/rich-people-like-to-read-2015-8), which breaks down to 1 per week
# - Bill wants you to read [these 5 books from 2019](https://time.com/5746591/bill-gates-best-books-2019/)
#
# ---

# %% [markdown]
# <h2 style="text-align:left; font-size:30px;">Elon Musk</h2>
#
# <caption style="text-align:left">Elon Reeve Musk is an engineer and technology entrepreneur. He holds South African, Canadian, and U.S. citizenship and is the founder, CEO, and chief engineer/designer of SpaceX; CEO and product architect of Tesla, Inc.; founder of The Boring Company; co-founder of Neuralink; and co-founder and initial co-chairman of OpenAI</caption>
#
# <center><img src="./imgs_charts/elon_2.jfif" style="float: center"
#          height="600" width="600"></center>
#
# <i>"The heroes of the books I read ... always felt a duty to save the world," ~ Elon Musk</i>
#
# [List](https://www.businessinsider.com/elon-musk-favorite-books-2014-10?op=1) of his favorite books
# [List](https://www.businessinsider.com/books-elon-musk-thinks-everyone-should-read-2018-4) of 12 books that shaped Elon
#
# ---

# %% [markdown]
# <h2 style="text-align:left; font-size:30px;">Oprah Winfrey</h2>
# <figcaption style="text-align:left">Oprah Gail Winfrey is an American media executive, actress, talk show host, television producer, and philanthropist. She is best known for her talk show, The Oprah Winfrey Show, broadcast from Chicago, which was the highest-rated television program of its kind in history and ran in national syndication for 25 years from 1986 to 2011</figcaption>
#
# <center>
#     <img src="./imgs_charts/oprah.jfif" style="float: center"
#          height="600" width="600">
# </center>
#
# <i>"Reading gave me the power to see possibilities beyond what was allowed at the time." ~ Oprah Gail Winfrey</i>
#
# ---

# %% [markdown]
# <h2 style="text-align:left; font-size:30px;">Larry Page</h2>
# <caption style="text-align:left;">Lawrence Edward Page is an American computer scientist and Internet entrepreneur. He is best known for being one of the co-founders of Google along with Sergey Brin. Page was the chief executive officer of Alphabet Inc. until stepping down on December 3, 2019</caption>
# <center>
#     <img src="./imgs_charts/larry_page.jpg" style="float: center"
#          height="600" width="600">
# </center>
#
# *‘It’s not necessary to go to school to launch a business. I read a whole shelf of business books and that was basically all I needed’.* ~ **Larry Page**
# [Books list](http://www.favobooks.com/enterpreneurs/110-Larry-Page-books-that-stimulate-your-mind.html) he was influenced by

# %% [markdown]
# <h2 style="text-align:left; font-size:30px;">Looks ok so far.. what about some science?</h2>
#
# A very small list of studies showing the measurable positive changes that reading has on the most important asset we posses in our lifetime: the brain.
#
# <ol>
#   <li style="text-align:left; font-size:15px;"><a href=https://srcd.onlinelibrary.wiley.com/doi/full/10.1111/cdev.12272> Increase intelligence</a></li>
#   <li style="text-align:left; font-size:15px;"><a href=https://n.neurology.org/content/81/4/314>It slows mental decline with age</a></li>
#   <li style="text-align:left; font-size:15px;"><a href=https://science.sciencemag.org/content/342/6156/377.abstract>Can make you more empathetic</a></li>
# </ol>
#
# ---

# %% [markdown]
# <center><img src="./imgs_charts/book.jpg" style="float: center"
#          height="700" width="700"></center>
#
# <a id="section2"></a>
# ---
#
# <h2 style="text-align:center; font-size:50px;">Analyze some reviews!</h2>
#
# <p>Welcome to the analysis section. Here you will look into the <a href="https://authorsmstevens.com/2019/06/26/the-ebook-vs-printed-book-debate/">book vs ebook</a> debate. I want to investigate what the data contained within the reviews can tell us.</p>

# %% [markdown]
# <h2 style="text-align:left; font-size:40px;">About the data</h2>
#
# ### List of what our data contains:
#
# <ul>
#   <li style="font-size:15px;"><b>review_id</b></li>
#   <ul>
#     <li>unique identifier for each row(observation) </li>
#   </ul>
#   <li style="font-size:15px;"><b>customer_id</b></li>
#   <li style="font-size:15px;"><b>product_id</b>, eg.,</li>
#   <ul>
#     <li>The Gulag Archipelago on <b>paper</b>
#       <ul>
#         <li>paper back<b> product_id:</b> A001</li>
#         <li>hard cover<b> product_id:</b> A002</li>
#         <li><b>...</b></li>
#       </ul>
#     <li>The Gulag Archipelago on <b>digital</b>
#       <ul>
#         <li>kindle<b> product_id:</b> B001</li>
#         <li>audio book<b> product_id:</b> B002</li>
#         <li><b>...</b></li>
#       </ul>
#   </ul>
#   <li style="font-size:15px;"><b>product_title</b></li>
#
#   <li style="font-size:15px;"><a href="https://www.businessinsider.com/how-amazon-review-stars-are-calculated-2019-6"><b>star_rating</b></a></li>
#   <li style="font-size:15px;"><a href="https://www.businessinsider.com/how-amazon-review-stars-are-calculated-2019-6"><b>verified_purchase</b></a></li>
#   <li style="font-size:15px;"><a href="https://www.amazon.com/gp/customer-reviews/top-reviewer-faq.html"><b>helpful_votes</b></a></li>
#   <li style="font-size:15px;"><b>total_votes</b></li>
#   <li style="font-size:15px;"><a href="https://www.amazon.com/gp/vine/help"><b>vine</b></a></li>
#   <li style="font-size:15px;"><b>review_date</b></li>
#
# </ul>

# %% [markdown]
# <a id="section3"></a>
#
# <img src=./imgs_charts/kindle.jpg atl='book' height="400" width="400" style="float: center"/>
#
# <h2 style="text-align:center; font-size:40px;">Did introduction of digital produce decline in verified purchases of paper books?</h2>
#
# ---
# <h2 style="text-align:left; font-size:20px;">Verified purchase reviews distributions chart below</h2>

# %%
from bokeh.plotting import figure, output_notebook, show, ColumnDataSource, output_file
from bokeh.models import HoverTool
from bokeh.layouts import column, row

from bokeh.io import curdoc
from bokeh.themes import Theme

from sqlalchemy import create_engine
import pandas as pd
import numpy as np
# output_notebook()

curdoc().theme = Theme(json={'attrs': {
'Figure': {
    'toolbar_location': 'right',
    'outline_line_color': None,
    'min_border_right': 10,
    'sizing_mode': 'stretch_width'
},'Grid': {
    'grid_line_color': None,
},
'Title': {
    'text_font_size': '14pt'
},# apply defaults to Axis properties
'Axis': {
    'minor_tick_out': None,
    'minor_tick_in': None,
    'major_label_text_font_size': '11pt',
    'axis_label_text_font_size': '13pt',
    'axis_label_text_font': 'Work Sans'
    
},
# apply defaults to Legend properties
'Legend': {
    'background_fill_alpha': 0.8,
    'border_line_color' : "black"
}}})

engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/amazon_reviews')
conn = engine.connect()

query = """SELECT review_date,star_rating FROM books WHERE CAST(review_date AS DATE) > '2010-11-28' AND verified_purchase = 1;"""
book_counts = pd.read_sql_query(query, con=engine, parse_dates='review_date').sample(frac=0.01)
book_counts['day_of_week'] = book_counts.review_date.dt.day_name().str.slice(0, 3)
query = """SELECT review_date,star_rating FROM digital_ebook_purchase WHERE CAST(review_date AS DATE) > '2010-11-28' AND verified_purchase = 1;"""
ebook_counts = pd.read_sql_query(query, con=engine, parse_dates='review_date').sample(frac=0.01)
ebook_counts['day_of_week'] = ebook_counts.review_date.dt.day_name().str.slice(0, 3)

# %%
from bokeh.transform import jitter

DAYS = ['Sun', 'Sat', 'Fri', 'Thu', 'Wed', 'Tue', 'Mon']

source1 = ColumnDataSource(book_counts)
p1 = figure(plot_width=625, plot_height=300, # for CAPSTONE,io plot_width=700, plot_height=300
            y_range=DAYS, x_axis_type='datetime', tools='', title=None)
p1.circle(x='review_date', 
          y=jitter('day_of_week', width=0.5, range=p1.y_range), 
          alpha=0.5, 
          source=source1,  
          color='black', 
          legend_label='books'
#           size='star_rating'
         )


source2 = ColumnDataSource(ebook_counts)
p2 = figure(plot_width=625, plot_height=300, # for CAPSTONE,io plot_width=700, plot_height=300
            y_range=DAYS, x_axis_type='datetime', tools='', title=None)
p2.circle(x='review_date', 
          y=jitter('day_of_week', width=0.5, range=p2.y_range),  
          alpha=0.4, 
          source=source2, 
          color='darkorange',
          legend_label='ebooks'
#           size='star_rating'
         )

p1.legend.location = "top_left"
p1.toolbar.logo = None
p2.legend.location = "top_left"
p2.toolbar.logo = None

## ORIGINAL
# output_file('./imgs_charts/1_verified_purchase_reviews.html', 'Verified Purchase Reviews')
# show(column([p1, p2],sizing_mode='stretch_both'))

## to CAPSTONE.io
# output_file('C:/Users/pluto/code_project_portfolio_git/CAPSTONE.io/imgs_charts/1_verified_purchase_reviews.html', 'Verified Purchase Reviews')
output_notebook()
show(column([p1, p2]))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1095">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c63ceb80-7a59-447b-9764-78984d071fae" data-root-id="1096"></div>

# %% [markdown]
# *For above charts, a random fractional sample of each format was taken(0.01) because of the size of the data set*
# **Observations:**
#
# - `Digital` has larger sample size and went into full swing on amazon market starting 2014. Despite this, `Paper` reviews seem to be going steady and not declining in frequency.
#
# ---
#
# <h3 style="text-align:left; font-size:15px;"><b>NOTE</b> Every chart from here on, use chart right-side toolbar to:</h3>
# <ul style="text-align:left; font-size:15px;">
#   <li style="text-align:left;"><b>PAN</b></li>
#   <li style="text-align:left;"><b>ZOOM</b></li>
#   <li style="text-align:left;"><b>HOVER</b> cursor for inspection of data points</li>
#   <li style="text-align:left;"><b>RESET</b> to re-align</li>
# </ul>
#
# ---
#
# <h2 style="text-align:left; font-size:20px;">Rolling average star rating Books vs eBooks</h2>

# %%
query = """
SELECT 
    review_date, 
    COUNT(review_id) AS count_reviews,
    ROUND(AVG(star_rating), 4) as avg_stars,
    ROUND(AVG(helpful_votes), 4) as avg_helpful,
    ROUND(AVG(total_votes), 4) as avg_total
    
FROM {} 
GROUP BY review_date 
ORDER BY review_date;
"""
books = pd.read_sql_query(query.format('books'), con=engine, 
                          index_col='review_date', 
                          parse_dates='review_date')

ebooks =pd.read_sql_query(query.format('digital_ebook_purchase'), con=engine, 
                          index_col='review_date',
                          parse_dates='review_date')

# %%
resampled_books = books.resample('2M').median()['1996-07-01':]
resampled_ebooks = ebooks.resample('2M').median()['2007-08-01':]

source_book = ColumnDataSource.from_df(resampled_books)
source_ebook = ColumnDataSource.from_df(resampled_ebooks)

p3 = figure(x_axis_type="datetime",y_range=(3.25, 5.25),
#             sizing_mode='stretch_width',
            plot_width=600, plot_height=600,  # FOR CAPSTONE.io plot_width=600, plot_height=400
            tools="crosshair,pan,wheel_zoom,box_zoom,reset,hover",)
p3.yaxis.axis_label = 'Star Rating'
p3.line(x='review_date', y='avg_stars', source=source_book, color="black", line_width=2.5, line_alpha=.5, legend_label='books')
p3.line(x='review_date', y='avg_stars', source=source_ebook, color="darkorange", line_width=2.5, line_alpha=0.8, legend_label='ebooks')


p3.circle(x='review_date', y='avg_stars', source=source_book, color="black", line_alpha=0.2, legend_label='books')
p3.circle(x='review_date', y='avg_stars', source=source_ebook, color="darkorange", line_alpha=0.5, legend_label='ebooks')

hover = p3.select(dict(type=HoverTool))
hover.tooltips = [("avg_stars", "@avg_stars"), ("review_date", "@review_date{%Y-%b}")]
hover.formatters={'review_date' : 'datetime', 'avg_stars': 'numeral'}
hover.mode = 'mouse'

p3.legend.location = "top_left"
p3.yaxis.major_label_orientation = "vertical"
p3.grid.grid_line_color = None
p3.toolbar.logo = None

# output_file('./imgs_charts/2_month_rolling_avg_star_ratings.html', '2 Month rolling average star rating')
# output_notebook()
# show(p3)

## TO CAPSTONE.io
# output_file('C:/Users/pluto/code_project_portfolio_git/CAPSTONE.io/imgs_charts/2_month_rolling_avg_star_ratings.html', '2 Month rolling average star rating')
output_notebook()
show(p3)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1538">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="cf757549-7045-44da-a775-d2f1e8e50e47" data-root-id="1363"></div>

# %% [markdown]
# **Observations:**
#
# - It took `Digital` from 2007 - 2012 to stabilize its rolling averages on Amazon Market
# - 2011 - 2012 both formats took a dip
# - Rolling average of `Paper` **OUTPERFORMS** `Digital` format starting 2014 - onward

# %% [markdown]
# <a id="section4"></a>
#
# <img src=./imgs_charts/books_1.jpg atl='book' height="700" width="800"/>

# %% [markdown]
# <center><h2 style="font-size:50px;">Analysis of Paper vs Digital Titles</h2></center>
#
# ---
#
# <h2 style="text-align:left; font-size:20px;">Top titles sorted by <b>star rating</b> with stacked <b>helpful review</b> counts for comparison</h2>

# %%
query = """SELECT 
	product_title,
	b.star_rating AS book_star, 
	e.star_rating AS ebook_star, 
	b.helpful_votes AS book_helpful, 
	e.helpful_votes AS ebook_helpful, 
	b.total_votes AS book_total, 
	e.total_votes AS ebook_total, 
	b.verified_purchase AS book_verified, 
	e.verified_purchase AS ebook_verified 
FROM (SELECT
		product_title,
		product_id,
		ROUND(AVG(star_rating), 4) AS star_rating,
		SUM(helpful_votes) AS helpful_votes,
		SUM(total_votes) AS total_votes,
		SUM(verified_purchase) AS verified_purchase
	FROM books 
	GROUP BY product_title, product_id
	HAVING COUNT(review_id) > 100 AND SUM(helpful_votes) > 200
) AS b 
JOIN (SELECT
		product_title,
		ROUND(AVG(star_rating), 4) AS star_rating,
		SUM(helpful_votes) AS helpful_votes,
		SUM(total_votes) AS total_votes,
		SUM(verified_purchase) AS verified_purchase
	FROM digital_ebook_purchase 
	GROUP BY product_title, product_id
	HAVING COUNT(review_id) > 100 AND SUM(helpful_votes) > 200
) as e USING(product_title);"""

both = pd.read_sql_query(query, con=engine)
both_grouped = both.groupby('product_title').agg(dict(zip(both.columns.to_list()[1:], [np.mean, np.mean, sum, sum, sum, sum, sum, sum])))

# %%
from collections import OrderedDict
from bokeh.plotting import figure

### PAPER

df = both_grouped.sort_values("book_star", ascending=False).head(15) # by book stars
titles = [i.title() for i in df.index.values.tolist()]
books_helpful = df.book_helpful.sort_values(ascending=False)
ebooks_helpful = df.ebook_helpful.sort_values(ascending=False)


stars = OrderedDict(titles=[i.title() for i in df.index.values],
                    books_helpful=books_helpful.values, 
                    ebooks_helpful=ebooks_helpful.values)

things = ['books_helpful', 'ebooks_helpful']
colors = ["#c9d9d3", "#718dbf"]
p4 = figure(x_range=stars['titles'], 
#            sizing_mode='stretch_width',
           plot_width=620, plot_height=300,
           title='Top star rated paper titles',
           toolbar_location='right', tools="pan,box_zoom,hover,reset",
           tooltips=[("Helpful Review Counts", "@$name"),
                     ("Title ", "@titles")]
          )
# [("avg_stars", "@avg_stars"), ("review_date", "@review_date{%Y-%b}")] ]
p4.vbar_stack(things, x='titles', width=0.9, source=stars, 
             color=['black', 'darkorange'], 
             alpha=0.7,
             legend_label=[i.split('_')[0] for i in things]
            )


p4.axis.minor_tick_line_color = None
p4.xaxis.major_label_text_color = None
p4.toolbar.logo = None
p4.legend.title = "helpful review counts for:"
### DIGITAL

df = both_grouped.sort_values("ebook_star", ascending=False).head(15) # by ebook stars
titles = [i.title() for i in df.index.values.tolist()]

books_helpful = df.book_helpful.sort_values(ascending=False)
ebooks_helpful = df.ebook_helpful.sort_values(ascending=False)

stars = OrderedDict(titles=[i.title() for i in df.index.values],
                    books_helpful=books_helpful.values, 
                    ebooks_helpful=ebooks_helpful.values)

things = ['books_helpful', 'ebooks_helpful']
colors = ["#c9d9d3", "#718dbf"]
p5 = figure(x_range=stars['titles'],
#             sizing_mode='stretch_width',
            plot_width=625, plot_height=300,
            title='Top star rated digital titles',
           toolbar_location='right', tools="pan,box_zoom,hover,reset",
           tooltips=[("Helpful Review Counts", "@$name"),
                     ("Title ", "@titles")]
          )

p5.vbar_stack(things, x='titles', width=0.9, source=stars, 
             color=['black', 'darkorange'], 
             alpha=0.7,
#              legend_label=[i.split('_')[0] for i in things]
            )
            
p5.axis.minor_tick_line_color = None
p5.xaxis.major_label_text_color = None
p5.toolbar.logo = None


## ORIGINAL
# output_file('./imgs_charts/3_helpful_votes_by_stars_both.html', 'Top 30 titles sorted by average star rating')
# show(column([p4, p5]),sizing_mode='stretch_both')

## TO CAPSTONE BOTH
# output_file('C:/Users/pluto/code_project_portfolio_git/CAPSTONE.io/imgs_charts/3_helpful_votes_by_stars_both.html', 'Top 30 titles sorted by average star rating')
show(column([p4, p5]))

# output_file('./imgs_charts/3_helpful_reviews_by_stars1.html', 'Top 30 titles by stars')
# show(p4)
# output_file('./imgs_charts/3_helpful_reviews_by_stars2.html', 'Top 30 titles by stars')
# show(p5)
# Out:
#   <div class="bk-root" id="717d1f9f-e1b8-4846-8769-3a65f6a0a2b1" data-root-id="1875"></div>

# %% [markdown]
# **Observation:**
#
# - Above charts top(`Paper`) and bottom(`Digital`) titles are sorted by their respective `star_rating`
#   - In all but three cases(`"Fearless", "Words of Radiance", "Being Mortal"`), `Paper` takes the cake in terms of helpful reviews written
#
# *NOTE FROM ANALYST: `Words of Radiance` is one book of an excellent fantasy series!*

# %% [markdown]
# ---
#
# <h2 style="text-align:left; font-size:20px;">Top titles sorted by <b>verified purchase</b> counts with stacked <b>helpful review</b> counts for comparison</h2>

# %%
df = both_grouped.sort_values("book_verified", ascending=False).head(15) # by book verified purchase
titles = [i.title() for i in df.index.values.tolist()]

books_helpful = df.book_helpful.sort_values(ascending=False)
ebooks_helpful = df.ebook_helpful.sort_values(ascending=False)

verified = OrderedDict(titles=[i.title() for i in df.index.values],
                    books_helpful=books_helpful.values, 
                    ebooks_helpful=ebooks_helpful.values)

things = ['books_helpful', 'ebooks_helpful']
colors = ["#c9d9d3", "#718dbf"]
p6 = figure(x_range=verified['titles'], 
            plot_width=625, plot_height=300, # CAPSTONE.io formatting plot_width=600, plot_height=300
           title='Top verified purchase paper titles',
           toolbar_location='right', tools="pan,box_zoom,hover,reset",
           tooltips="count: @$name @titles"
          )

p6.vbar_stack(things, x='titles', width=0.9, source=verified, 
             color=['black', 'darkorange'], 
             alpha=0.7,
             legend_label=[i.split('_')[0] for i in things]
            )

p6.axis.minor_tick_line_color = None
p6.xaxis.major_label_text_color = None
p6.toolbar.logo = None
p6.legend.title = "helpful review counts for:"

### DIGITAL

df = both_grouped.sort_values("ebook_verified", ascending=False).head(15) # by ebook verified purchase
titles = [i.title() for i in df.index.values.tolist()]

books_helpful = df.book_helpful.sort_values(ascending=False)
ebooks_helpful = df.ebook_helpful.sort_values(ascending=False)

verified = OrderedDict(titles=[i.title() for i in df.index.values],
                    books_helpful=books_helpful.values, 
                    ebooks_helpful=ebooks_helpful.values)

things = ['books_helpful', 'ebooks_helpful']
colors = ["#c9d9d3", "#718dbf"]
p7 = figure(x_range=verified['titles'], 
            plot_width=625, plot_height=300, # CAPSTONE.io formatting plot_width=600, plot_height=300
            title='Top verified purchase digital titles',
           toolbar_location='right', tools="pan,box_zoom,hover,reset",
           tooltips="count: @$name @titles"
          )

p7.vbar_stack(things, x='titles', width=0.9, source=verified, 
             color=['black', 'darkorange'], 
             alpha=0.7,
#              legend_label=[i.split('_')[0] for i in things] # no need for two legends
            )
            
p7.axis.minor_tick_line_color = None
p7.xaxis.major_label_text_color = None
p7.toolbar.logo = None

# output_file('./imgs_charts/4_helpful_votes_by_verified_purchase.html', 'Top 30 titles sorted by average star verified purchase')

# output_file('C:/Users/pluto/code_project_portfolio_git/CAPSTONE.io/imgs_charts/4_helpful_votes_by_verified_both.html', 'Top 30 titles sorted by verified purchase rating')



show(column([p6, p7]))
# Out:
#   <div class="bk-root" id="13d30d4c-4ca9-48a7-a6b5-9ab05a8f41bb" data-root-id="2190"></div>

# %% [markdown]
# **Observation:**
# - Above charts top(`Paper`) and bottom(`Digital`) titles are sorted by their respective `verified_purchase` sums
#   - In all but one case(`The Fault In Our Stars`), `Paper`, again takes the cake

# %% [markdown]
# <a id="section4"></a>
#
# <img src=./imgs_charts/book_vs_ebook.jpg atl='book' height="700" width="800"/>
#
# <h2 style="text-align:left; font-size:50px;">Recommendations</h2>
#
# According to this simple analysis, `Paper` takes the cake, at least in terms of review quality. My recommendation? Buy whatever you want, but read the `Paper` reviews as they seem to be very helpful according to hundreds of thousands of review-readers.
# More reading in general is a great idea, so I am not partial to either substrate. Also, cost wasn't taken into consideration during this analysis and that can play a large role in decision making of purchases.
#
# Thanks for reading!
#
# *A notebook with just the notation and interactive charts(no code) will be made available soon*
